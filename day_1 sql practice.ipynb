# %% [markdown]
# <a href="https://colab.research.google.com/github/Anu-0107/sql-practice/blob/main/day_1%20sql%20practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
CREATE DATABASE temp1;
